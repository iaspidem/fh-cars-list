# %%
import pandas as pd

# %%
df = pd.read_csv("FH5/FH5-0-owned.csv", encoding="cp1252")
df.head()
# Out:
#     Brand          Vehicle  Year     Value       Collection  Rarity     PI  \
# 0  Abarth    595 esseesse   1968    35,000         Autoshow  COMMON  D 100
# 1  Abarth        Fiat 131   1980   250,000   "Hard to Find"  COMMON  C 510
# 2  Abarth     695 Biposto   2016   250,000   "Hard to Find"  COMMON  B 657
# 3  Abarth      124 Spider   2017   250,000   "Hard to Find"  COMMON  C 562
# 4   Acura  Integra Type-R   2001    25,000         Autoshow  COMMON  C 596
#
#   Owned
# 0   NaN
# 1     1
# 2     1
# 3   NaN
# 4   NaN

# %%
df.dtypes
# Out:
# Brand           str
# Vehicle         str
# Year          int64
#  Value          str
# Collection      str
# Rarity          str
# PI              str
# Owned           str
# dtype: object

# %%
df["Year"] = df["Year"].astype(str)
df.dtypes
# Out:
# Brand         str
# Vehicle       str
# Year          str
#  Value        str
# Collection    str
# Rarity        str
# PI            str
# Owned         str
# dtype: object

# %%
df["Owned"] = df["Owned"].fillna("1")
df.head()
# Out:
#     Brand          Vehicle  Year     Value       Collection  Rarity     PI  \
# 0  Abarth    595 esseesse   1968    35,000         Autoshow  COMMON  D 100
# 1  Abarth        Fiat 131   1980   250,000   "Hard to Find"  COMMON  C 510
# 2  Abarth     695 Biposto   2016   250,000   "Hard to Find"  COMMON  B 657
# 3  Abarth      124 Spider   2017   250,000   "Hard to Find"  COMMON  C 562
# 4   Acura  Integra Type-R   2001    25,000         Autoshow  COMMON  C 596
#
#   Owned
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
df["Owned"].value_counts()
# Out:
# Owned
# 1    758
# 0     94
# -     50
# Name: count, dtype: int64

# %%
df = df.sort_values(["Brand", "Year", "Vehicle"], ascending=[True, True, True], key=lambda col: col.str.lower())
df = df.reset_index(drop=True)
df.head()
# Out:
#     Brand          Vehicle  Year     Value       Collection  Rarity     PI  \
# 0  Abarth    595 esseesse   1968    35,000         Autoshow  COMMON  D 100
# 1  Abarth        Fiat 131   1980   250,000   "Hard to Find"  COMMON  C 510
# 2  Abarth     695 Biposto   2016   250,000   "Hard to Find"  COMMON  B 657
# 3  Abarth      124 Spider   2017   250,000   "Hard to Find"  COMMON  C 562
# 4   Acura  Integra Type-R   2001    25,000         Autoshow  COMMON  C 596
#
#   Owned
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
df_notowned = df.iloc[df["Owned"].str.contains("0")]
df_notowned.head()
# Out:
#            Brand                           Vehicle  Year        Value   \
# 8     Alfa Romeo                       Giulia TZ2   1965    4,000,000
# 9     Alfa Romeo                      33 Stradale   1968   15,000,000
# 28  Aston Martin                             DBR1   1958   22,500,000
# 71    Auto Union                           Type D   1939   15,000,000
# 76       Bentley  Blower 4-1/2 Litre Supercharged   1931    4,000,000
#
#                                 Collection     Rarity     PI Owned
# 8                                 Autoshow  LEGENDARY  B 641     0
# 9                                 Autoshow  LEGENDARY  A 707     0
# 28                                Autoshow  LEGENDARY  B 678     0
# 71  Autoshow, "Fairy Tale Ending" accolade  LEGENDARY  B 675     0
# 76                     Autoshow, Wheelspin  LEGENDARY  D 207     0

# %%
df_notowned_htf = df_notowned[df_notowned["Collection"].str.contains("Hard to Find")]
df_notowned_htf.head()
# Out:
#          Brand                       Vehicle  Year     Value       Collection  \
# 212  Extreme E            #125 ABT Cupra XE   2022   700,000   "Hard to Find"
# 213  Extreme E                     #22 JBXE   2022   700,000   "Hard to Find"
# 214  Extreme E  #23 Genesys Andretti United   2022   700,000   "Hard to Find"
# 216  Extreme E                      #44 X44   2022   700,000   "Hard to Find"
# 218  Extreme E  #55 ACCIONA | Sainz XE Team   2022   700,000   "Hard to Find"
#
#     Rarity     PI Owned
# 212   RARE  A 748     0
# 213   RARE  A 748     0
# 214   RARE  A 748     0
# 216   RARE  A 748     0
# 218   RARE  A 748     0

# %%
df_save = df_notowned_htf.copy()

# %%
df_save["Vehicle"] = df_notowned_htf["Brand"] + " " + df_notowned_htf["Vehicle"] + "(" + df_notowned_htf["Year"] + ")"
df_save.head()
# Out:
#          Brand                                       Vehicle  Year     Value   \
# 212  Extreme E            Extreme E #125 ABT Cupra XE (2022)  2022   700,000
# 213  Extreme E                     Extreme E #22 JBXE (2022)  2022   700,000
# 214  Extreme E  Extreme E #23 Genesys Andretti United (2022)  2022   700,000
# 216  Extreme E                      Extreme E #44 X44 (2022)  2022   700,000
# 218  Extreme E  Extreme E #55 ACCIONA | Sainz XE Team (2022)  2022   700,000
#
#          Collection Rarity     PI Owned
# 212  "Hard to Find"   RARE  A 748     0
# 213  "Hard to Find"   RARE  A 748     0
# 214  "Hard to Find"   RARE  A 748     0
# 216  "Hard to Find"   RARE  A 748     0
# 218  "Hard to Find"   RARE  A 748     0

# %%
columns_to_drop = [0, 2]
df_save = df_save.drop(df_save.columns[columns_to_drop], axis=1)
df_save.head()
# Out:
#                                           Vehicle     Value       Collection  \
# 212            Extreme E #125 ABT Cupra XE (2022)   700,000   "Hard to Find"
# 213                     Extreme E #22 JBXE (2022)   700,000   "Hard to Find"
# 214  Extreme E #23 Genesys Andretti United (2022)   700,000   "Hard to Find"
# 216                      Extreme E #44 X44 (2022)   700,000   "Hard to Find"
# 218  Extreme E #55 ACCIONA | Sainz XE Team (2022)   700,000   "Hard to Find"
#
#     Rarity     PI Owned
# 212   RARE  A 748     0
# 213   RARE  A 748     0
# 214   RARE  A 748     0
# 216   RARE  A 748     0
# 218   RARE  A 748     0

# %%
df_nonautoshow = df_notowned[~df_notowned["Collection"].str.contains("Autoshow")]
df_nonautoshow["Vehicle"] = df_nonautoshow["Year"] + " " + df_nonautoshow["Brand"] + " " + df_nonautoshow["Vehicle"]
df_nonautoshow = df_nonautoshow.drop(df_nonautoshow.columns[columns_to_drop], axis=1)
df_nonautoshow.head()
# Out:
#                                          Vehicle     Value       Collection  \
# 212            2022 Extreme E #125 ABT Cupra XE    700,000   "Hard to Find"
# 213                     2022 Extreme E #22 JBXE    700,000   "Hard to Find"
# 214  2022 Extreme E #23 Genesys Andretti United    700,000   "Hard to Find"
# 216                      2022 Extreme E #44 X44    700,000   "Hard to Find"
# 218  2022 Extreme E #55 ACCIONA | Sainz XE Team    700,000   "Hard to Find"
#
#     Rarity     PI Owned
# 212   RARE  A 748     0
# 213   RARE  A 748     0
# 214   RARE  A 748     0
# 216   RARE  A 748     0
# 218   RARE  A 748     0

# %%
df_save.to_csv("FH5/FH5-missingHtF.csv", index=False, encoding="utf-8-sig")
df_nonautoshow.to_csv("FH5/FH5-nonautoshow.csv", index=False, encoding="utf-8-sig")
