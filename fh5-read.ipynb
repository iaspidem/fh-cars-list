# %%
import pandas as pd

# %%
df = pd.read_csv("FH5/FH5-0-owned.csv", encoding="cp1252")
df.head()
# Out:
#     Brand          Vehicle  Year     Value       Collection  Rarity     PI  \
# 0  Abarth    595 esseesse   1968    35,000         Autoshow  COMMON  D 100
# 1  Abarth        Fiat 131   1980   250,000   "Hard to Find"  COMMON  C 510
# 2  Abarth     695 Biposto   2016   250,000   "Hard to Find"  COMMON  B 657
# 3  Abarth      124 Spider   2017   250,000   "Hard to Find"  COMMON  C 562
# 4   Acura  Integra Type-R   2001    25,000         Autoshow  COMMON  C 596
#
#   Owned
# 0   NaN
# 1     0
# 2     0
# 3   NaN
# 4   NaN

# %%
df.dtypes
# Out:
# Brand           str
# Vehicle         str
# Year          int64
#  Value          str
# Collection      str
# Rarity          str
# PI              str
# Owned           str
# dtype: object

# %%
df["Year"] = df["Year"].astype(str)
df.dtypes
# Out:
# Brand         str
# Vehicle       str
# Year          str
#  Value        str
# Collection    str
# Rarity        str
# PI            str
# Owned         str
# dtype: object

# %%
df["Owned"] = df["Owned"].fillna("1")
df.head()
# Out:
#     Brand          Vehicle  Year     Value       Collection  Rarity     PI  \
# 0  Abarth    595 esseesse   1968    35,000         Autoshow  COMMON  D 100
# 1  Abarth        Fiat 131   1980   250,000   "Hard to Find"  COMMON  C 510
# 2  Abarth     695 Biposto   2016   250,000   "Hard to Find"  COMMON  B 657
# 3  Abarth      124 Spider   2017   250,000   "Hard to Find"  COMMON  C 562
# 4   Acura  Integra Type-R   2001    25,000         Autoshow  COMMON  C 596
#
#   Owned
# 0     1
# 1     0
# 2     0
# 3     1
# 4     1

# %%
df["Owned"].value_counts()
# Out:
# Owned
# 1    684
# 0    167
# -     51
# Name: count, dtype: int64

# %%
df = df.sort_values(["Brand", "Year", "Vehicle"], ascending=[True, True, True], key=lambda col: col.str.lower())
df = df.reset_index(drop=True)
df.head()
# Out:
#     Brand          Vehicle  Year     Value       Collection  Rarity     PI  \
# 0  Abarth    595 esseesse   1968    35,000         Autoshow  COMMON  D 100
# 1  Abarth        Fiat 131   1980   250,000   "Hard to Find"  COMMON  C 510
# 2  Abarth     695 Biposto   2016   250,000   "Hard to Find"  COMMON  B 657
# 3  Abarth      124 Spider   2017   250,000   "Hard to Find"  COMMON  C 562
# 4   Acura  Integra Type-R   2001    25,000         Autoshow  COMMON  C 596
#
#   Owned
# 0     1
# 1     0
# 2     0
# 3     1
# 4     1

# %%
df_notowned = df.iloc[df["Owned"].str.contains("0")]
df_notowned.head()
# Out:
#          Brand           Vehicle  Year        Value       Collection  \
# 1       Abarth         Fiat 131   1980      250,000   "Hard to Find"
# 2       Abarth      695 Biposto   2016      250,000   "Hard to Find"
# 8   Alfa Romeo       Giulia TZ2   1965    4,000,000         Autoshow
# 9   Alfa Romeo      33 Stradale   1968   15,000,000         Autoshow
# 11  Alfa Romeo  8C Competizione   2007      300,000   "Hard to Find"
#
#        Rarity     PI Owned
# 1      COMMON  C 510     0
# 2      COMMON  B 657     0
# 8   LEGENDARY  B 641     0
# 9   LEGENDARY  A 707     0
# 11       EPIC  A 755     0

# %%
df_notowned_htf = df_notowned[df_notowned["Collection"].str.contains("Hard to Find")]
df_notowned_htf.head()
# Out:
#          Brand           Vehicle  Year     Value       Collection  Rarity  \
# 1       Abarth         Fiat 131   1980   250,000   "Hard to Find"  COMMON
# 2       Abarth      695 Biposto   2016   250,000   "Hard to Find"  COMMON
# 11  Alfa Romeo  8C Competizione   2007   300,000   "Hard to Find"    EPIC
# 12  Alfa Romeo               4C   2014   250,000   "Hard to Find"    RARE
# 27      Ascari             KZ1R   2012   250,000   "Hard to Find"    EPIC
#
#         PI Owned
# 1    C 510     0
# 2    B 657     0
# 11   A 755     0
# 12   A 755     0
# 27  S1 829     0

# %%
df_save = df_notowned_htf.copy()

# %%
df_save["Vehicle"] = df_notowned_htf["Brand"] + " " + df_notowned_htf["Vehicle"] + "(" + df_notowned_htf["Year"] + ")"
df_save.head()
# Out:
#          Brand                            Vehicle  Year     Value   \
# 1       Abarth             Abarth Fiat 131 (1980)  1980   250,000
# 2       Abarth          Abarth 695 Biposto (2016)  2016   250,000
# 11  Alfa Romeo  Alfa Romeo 8C Competizione (2007)  2007   300,000
# 12  Alfa Romeo               Alfa Romeo 4C (2014)  2014   250,000
# 27      Ascari                 Ascari KZ1R (2012)  2012   250,000
#
#         Collection  Rarity      PI Owned
# 1   "Hard to Find"  COMMON   C 510     0
# 2   "Hard to Find"  COMMON   B 657     0
# 11  "Hard to Find"    EPIC   A 755     0
# 12  "Hard to Find"    RARE   A 755     0
# 27  "Hard to Find"    EPIC  S1 829     0

# %%
columns_to_drop = [0, 2]
df_save = df_save.drop(df_save.columns[columns_to_drop], axis=1)
df_save.head()
# Out:
#                               Vehicle     Value       Collection  Rarity  \
# 1              Abarth Fiat 131 (1980)   250,000   "Hard to Find"  COMMON
# 2           Abarth 695 Biposto (2016)   250,000   "Hard to Find"  COMMON
# 11  Alfa Romeo 8C Competizione (2007)   300,000   "Hard to Find"    EPIC
# 12               Alfa Romeo 4C (2014)   250,000   "Hard to Find"    RARE
# 27                 Ascari KZ1R (2012)   250,000   "Hard to Find"    EPIC
#
#         PI Owned
# 1    C 510     0
# 2    B 657     0
# 11   A 755     0
# 12   A 755     0
# 27  S1 829     0

# %%
df_save.to_csv("FH5/FH5-missingHtF.csv", index=False, encoding="utf-8-sig")
