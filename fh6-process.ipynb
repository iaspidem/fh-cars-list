# %%
import pandas as pd

# %% [markdown]
# # Import raw data for preprocessing

# %%
filename = "fh6cars-15-07-26"
tables = pd.read_html(filename + ".htm")
df = tables[1]
df.head()
# Out:
#                                              Vehicle   🔓   🦄   📅   🌍  \
# 0               Abarth 124 Spider 2017"Hard to Find" NaN NaN NaN NaN
# 1              Abarth 695 Biposto 2016"Hard to Find" NaN NaN NaN NaN
# 2            Abarth Fiat 131 1980Autoshow, Wheelspin NaN NaN NaN NaN
# 3        Abarth 595 esseesse 1968Autoshow, Wheelspin NaN NaN NaN NaN
# 4  Acura Integra A-Spec 2023Autoshow, Wheelspin, ... NaN NaN NaN NaN
#
#               Value   Sp   Ha   Ac   La   Br   Of    PI
# 0    250,000 CRRARE  5.2  4.7  3.8  4.6  3.3  5.5  C450
# 1  250,000 CRCOMMON  4.9  5.3  4.7  3.9  4.8  5.1  B540
# 2  125,000 CRCOMMON  4.3  4.1  4.1  3.9  3.2  5.9  D399
# 3   25,000 CRCOMMON  2.6  3.7  1.7  2.6  2.0  5.2  D100
# 4     36,000 CRRARE  5.7  4.7  4.2  4.2  3.7  5.5  C484

# %% [markdown]
# ## Remove redundant columns

# %%
columns_to_drop = [1, 2, 3, 4]
df = df.drop(df.columns[columns_to_drop], axis=1)
df.head()
# Out:
#                                              Vehicle             Value   Sp  \
# 0               Abarth 124 Spider 2017"Hard to Find"    250,000 CRRARE  5.2
# 1              Abarth 695 Biposto 2016"Hard to Find"  250,000 CRCOMMON  4.9
# 2            Abarth Fiat 131 1980Autoshow, Wheelspin  125,000 CRCOMMON  4.3
# 3        Abarth 595 esseesse 1968Autoshow, Wheelspin   25,000 CRCOMMON  2.6
# 4  Acura Integra A-Spec 2023Autoshow, Wheelspin, ...     36,000 CRRARE  5.7
#
#     Ha   Ac   La   Br   Of    PI
# 0  4.7  3.8  4.6  3.3  5.5  C450
# 1  5.3  4.7  3.9  4.8  5.1  B540
# 2  4.1  4.1  3.9  3.2  5.9  D399
# 3  3.7  1.7  2.6  2.0  5.2  D100
# 4  4.7  4.2  4.2  3.7  5.5  C484

# %% [markdown]
# ## Expand abbreviated columns

# %%
df = df.rename(columns={"Sp": "Speed", "Ha": "Handling", "Ac": "Accel", "La": "Launch", "Br": "Braking", "Of": "OffRd"})
df.head()
# Out:
#                                              Vehicle             Value  Speed  \
# 0               Abarth 124 Spider 2017"Hard to Find"    250,000 CRRARE    5.2
# 1              Abarth 695 Biposto 2016"Hard to Find"  250,000 CRCOMMON    4.9
# 2            Abarth Fiat 131 1980Autoshow, Wheelspin  125,000 CRCOMMON    4.3
# 3        Abarth 595 esseesse 1968Autoshow, Wheelspin   25,000 CRCOMMON    2.6
# 4  Acura Integra A-Spec 2023Autoshow, Wheelspin, ...     36,000 CRRARE    5.7
#
#    Handling  Accel  Launch  Braking  OffRd    PI
# 0       4.7    3.8     4.6      3.3    5.5  C450
# 1       5.3    4.7     3.9      4.8    5.1  B540
# 2       4.1    4.1     3.9      3.2    5.9  D399
# 3       3.7    1.7     2.6      2.0    5.2  D100
# 4       4.7    4.2     4.2      3.7    5.5  C484

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Vehicle   627 non-null    str
#  1   Value     627 non-null    str
#  2   Speed     627 non-null    float64
#  3   Handling  627 non-null    float64
#  4   Accel     627 non-null    float64
#  5   Launch    627 non-null    float64
#  6   Braking   627 non-null    float64
#  7   OffRd     627 non-null    float64
#  8   PI        627 non-null    str
# dtypes: float64(6), str(3)
# memory usage: 44.2 KB

# %% [markdown]
# ## Remove stat columns from df_lite

# %%
columns_to_drop = [2, 3, 4, 5, 6, 7]
df_lite = df.drop(df.columns[columns_to_drop], axis=1)
df_lite.head()
# Out:
#                                              Vehicle             Value    PI
# 0               Abarth 124 Spider 2017"Hard to Find"    250,000 CRRARE  C450
# 1              Abarth 695 Biposto 2016"Hard to Find"  250,000 CRCOMMON  B540
# 2            Abarth Fiat 131 1980Autoshow, Wheelspin  125,000 CRCOMMON  D399
# 3        Abarth 595 esseesse 1968Autoshow, Wheelspin   25,000 CRCOMMON  D100
# 4  Acura Integra A-Spec 2023Autoshow, Wheelspin, ...     36,000 CRRARE  C484

# %% [markdown]
# ## Split original Value column into Value and Rarity

# %%
df_lite[["Value", "Rarity"]] = df["Value"].str.split("CR", n=1, expand=True)
df_lite = df_lite.iloc[:, [0, 1, 3, 2]]

df_lite["Value"] = df_lite["Value"].str.replace(",", "")
df_lite["Value"] = df_lite["Value"].str.replace("?", "0")
df_lite["Value"] = df_lite["Value"].astype(int)
df_lite.head()
# Out:
#                                              Vehicle   Value  Rarity    PI
# 0               Abarth 124 Spider 2017"Hard to Find"  250000    RARE  C450
# 1              Abarth 695 Biposto 2016"Hard to Find"  250000  COMMON  B540
# 2            Abarth Fiat 131 1980Autoshow, Wheelspin  125000  COMMON  D399
# 3        Abarth 595 esseesse 1968Autoshow, Wheelspin   25000  COMMON  D100
# 4  Acura Integra A-Spec 2023Autoshow, Wheelspin, ...   36000    RARE  C484

# %% [markdown]
# ## Split original Vehicle column into Brand and Vehicle

# %%
df_lite[["Brand", "Vehicle"]] = df_lite["Vehicle"].str.split(" ", n=1, expand=True)
df_lite = df_lite.iloc[:, [4, 0, 1, 2, 3]]
df_lite.head()
# Out:
#     Brand                                            Vehicle   Value  Rarity  \
# 0  Abarth                      124 Spider 2017"Hard to Find"  250000    RARE
# 1  Abarth                     695 Biposto 2016"Hard to Find"  250000  COMMON
# 2  Abarth                   Fiat 131 1980Autoshow, Wheelspin  125000  COMMON
# 3  Abarth               595 esseesse 1968Autoshow, Wheelspin   25000  COMMON
# 4   Acura  Integra A-Spec 2023Autoshow, Wheelspin, Afterm...   36000    RARE
#
#      PI
# 0  C450
# 1  B540
# 2  D399
# 3  D100
# 4  C484

# %% [markdown]
# ## Create Boolean columns for method of obtaining

# %%
df_lite["Autoshow"] = df_lite["Vehicle"].str.contains("Autoshow")
df_lite["Hard to Find"] = df_lite["Vehicle"].str.contains("Hard to Find")
df_lite["Wheelspin"] = df_lite["Vehicle"].str.contains("Wheelspin")
df_lite["Aftermarket Car"] = df_lite["Vehicle"].str.contains("Aftermarket Car")
df_lite["Collection Journal"] = df_lite["Vehicle"].str.contains("Collection Journal")
df_lite.head()
# Out:
#     Brand                                            Vehicle   Value  Rarity  \
# 0  Abarth                      124 Spider 2017"Hard to Find"  250000    RARE
# 1  Abarth                     695 Biposto 2016"Hard to Find"  250000  COMMON
# 2  Abarth                   Fiat 131 1980Autoshow, Wheelspin  125000  COMMON
# 3  Abarth               595 esseesse 1968Autoshow, Wheelspin   25000  COMMON
# 4   Acura  Integra A-Spec 2023Autoshow, Wheelspin, Afterm...   36000    RARE
#
#      PI  Autoshow  Hard to Find  Wheelspin  Aftermarket Car  \
# 0  C450     False          True      False            False
# 1  B540     False          True      False            False
# 2  D399      True         False       True            False
# 3  D100      True         False       True            False
# 4  C484      True         False       True             True
#
#    Collection Journal
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False

# %%
df_lite.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Brand               627 non-null    str
#  1   Vehicle             627 non-null    str
#  2   Value               627 non-null    int64
#  3   Rarity              627 non-null    str
#  4   PI                  627 non-null    str
#  5   Autoshow            627 non-null    bool
#  6   Hard to Find        627 non-null    bool
#  7   Wheelspin           627 non-null    bool
#  8   Aftermarket Car     627 non-null    bool
#  9   Collection Journal  627 non-null    bool
# dtypes: bool(5), int64(1), str(4)
# memory usage: 27.7 KB

# %% [markdown]
# ## Filter to cars that are obtainable via Autoshow and Wheelspin

# %%
df_sort = df_lite[df_lite["Vehicle"].str.contains("Autoshow, Wheelspin")]
df_sort.head()
# Out:
#     Brand                                            Vehicle   Value  Rarity  \
# 2  Abarth                   Fiat 131 1980Autoshow, Wheelspin  125000  COMMON
# 3  Abarth               595 esseesse 1968Autoshow, Wheelspin   25000  COMMON
# 4   Acura  Integra A-Spec 2023Autoshow, Wheelspin, Afterm...   36000    RARE
# 6   Acura  RSX Type S 2002Autoshow, Wheelspin, Aftermarke...   18000  COMMON
# 7   Acura             Integra Type R 2001Autoshow, Wheelspin   25000  COMMON
#
#      PI  Autoshow  Hard to Find  Wheelspin  Aftermarket Car  \
# 2  D399      True         False       True            False
# 3  D100      True         False       True            False
# 4  C484      True         False       True             True
# 6  C462      True         False       True             True
# 7  C471      True         False       True            False
#
#    Collection Journal
# 2               False
# 3               False
# 4               False
# 6               False
# 7               False

# %%
df_sort.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 397 entries, 2 to 626
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Brand               397 non-null    str
#  1   Vehicle             397 non-null    str
#  2   Value               397 non-null    int64
#  3   Rarity              397 non-null    str
#  4   PI                  397 non-null    str
#  5   Autoshow            397 non-null    bool
#  6   Hard to Find        397 non-null    bool
#  7   Wheelspin           397 non-null    bool
#  8   Aftermarket Car     397 non-null    bool
#  9   Collection Journal  397 non-null    bool
# dtypes: bool(5), int64(1), str(4)
# memory usage: 20.5 KB

# %% [markdown]
# ## Sort vehicles by brand, then lowest to highest cost

# %%
#df_sort = df_sort.sort_values(["Vehicle", "Value"], ascending=[True, True])
df_sort = df_sort.sort_values(["Brand", "Value"], ascending=[True, True])
#df_sort = df_sort[df_sort["Value"] <= 500000]
df_sort.head()
# Out:
#     Brand                                            Vehicle   Value  Rarity  \
# 3  Abarth               595 esseesse 1968Autoshow, Wheelspin   25000  COMMON
# 2  Abarth                   Fiat 131 1980Autoshow, Wheelspin  125000  COMMON
# 6   Acura  RSX Type S 2002Autoshow, Wheelspin, Aftermarke...   18000  COMMON
# 7   Acura             Integra Type R 2001Autoshow, Wheelspin   25000  COMMON
# 4   Acura  Integra A-Spec 2023Autoshow, Wheelspin, Afterm...   36000    RARE
#
#      PI  Autoshow  Hard to Find  Wheelspin  Aftermarket Car  \
# 3  D100      True         False       True            False
# 2  D399      True         False       True            False
# 6  C462      True         False       True             True
# 7  C471      True         False       True            False
# 4  C484      True         False       True             True
#
#    Collection Journal
# 3               False
# 2               False
# 6               False
# 7               False
# 4               False

# %%
df_sort.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 397 entries, 3 to 626
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Brand               397 non-null    str
#  1   Vehicle             397 non-null    str
#  2   Value               397 non-null    int64
#  3   Rarity              397 non-null    str
#  4   PI                  397 non-null    str
#  5   Autoshow            397 non-null    bool
#  6   Hard to Find        397 non-null    bool
#  7   Wheelspin           397 non-null    bool
#  8   Aftermarket Car     397 non-null    bool
#  9   Collection Journal  397 non-null    bool
# dtypes: bool(5), int64(1), str(4)
# memory usage: 20.5 KB

# %% [markdown]
# ### Convert dataframes to csv

# %%
df_sort.to_csv(filename + "-sorted" + ".csv", index=False)

# %%
df_lite.to_csv(filename + ".csv", index=False)

# %% [markdown]
# ## Filter to Wheelspin-exclusive cars

# %%
df_wheelspin = df_lite.loc[(df_lite["Autoshow"] == False) & (df_lite["Wheelspin"] == True)]
df_wheelspin = df_wheelspin.drop(columns=["Hard to Find", "Aftermarket Car"])
df_wheelspin.head()
# Out:
#       Brand                                    Vehicle    Value     Rarity  \
# 21   Apollo             Intensa Emozione 2019Wheelspin  3200000  LEGENDARY
# 27    Aston  Martin Valhalla Concept Car 2019Wheelspin  1150000  LEGENDARY
# 28    Aston      Martin DBS Superleggera 2019Wheelspin   275000       EPIC
# 57     Audi                Sport quattro 1983Wheelspin   650000       EPIC
# 62  Bentley                     Bentayga 2016Wheelspin   250000       EPIC
#
#        PI  Autoshow  Wheelspin  Collection Journal
# 21   R916     False       True               False
# 27   R960     False       True               False
# 28  S1736     False       True               False
# 57   B526     False       True               False
# 62   A612     False       True               False

# %%
df_wheelspin["Rarity"].value_counts()
# Out:
# Rarity
# EPIC             26
# LEGENDARY        11
# FORZA EDITION     8
# RARE              1
# Name: count, dtype: int64

# %% [markdown]
# ### Associate each rarity with numerical value

# %%
rarity_dict = {"COMMON": 1, "RARE": 2, "EPIC": 3, "LEGENDARY": 4, "FORZA EDITION": 5}
df_wheelspin["Rarity Value"] = df_wheelspin["Rarity"].map(rarity_dict)
df_wheelspin.head()
# Out:
#       Brand                                    Vehicle    Value     Rarity  \
# 21   Apollo             Intensa Emozione 2019Wheelspin  3200000  LEGENDARY
# 27    Aston  Martin Valhalla Concept Car 2019Wheelspin  1150000  LEGENDARY
# 28    Aston      Martin DBS Superleggera 2019Wheelspin   275000       EPIC
# 57     Audi                Sport quattro 1983Wheelspin   650000       EPIC
# 62  Bentley                     Bentayga 2016Wheelspin   250000       EPIC
#
#        PI  Autoshow  Wheelspin  Collection Journal  Rarity Value
# 21   R916     False       True               False             4
# 27   R960     False       True               False             4
# 28  S1736     False       True               False             3
# 57   B526     False       True               False             3
# 62   A612     False       True               False             3

# %% [markdown]
# ### Sort Wheelspin-exclusives according to Rarity

# %%
df_wheelspin = df_wheelspin.sort_values(["Rarity Value", "Brand"], ascending=[True, True])
df_wheelspin.head()
# Out:
#        Brand                                            Vehicle   Value  \
# 602   Toyota  Sports 800 1965Wheelspin, Earn 4,000 points in...  250000
# 28     Aston              Martin DBS Superleggera 2019Wheelspin  275000
# 57      Audi                        Sport quattro 1983Wheelspin  650000
# 71       BMW  M2 Competition Coupé 2020Wheelspin, Earn the Y...  250000
# 62   Bentley                             Bentayga 2016Wheelspin  250000
#
#     Rarity     PI  Autoshow  Wheelspin  Collection Journal  Rarity Value
# 602   RARE   D141     False       True                True             2
# 28    EPIC  S1736     False       True               False             3
# 57    EPIC   B526     False       True               False             3
# 71    EPIC   A656     False       True               False             3
# 62    EPIC   A612     False       True               False             3

# %%
df_wheelspin = df_wheelspin.drop(columns=["Rarity Value"])
df_wheelspin.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 46 entries, 602 to 624
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Brand               46 non-null     str
#  1   Vehicle             46 non-null     str
#  2   Value               46 non-null     int64
#  3   Rarity              46 non-null     str
#  4   PI                  46 non-null     str
#  5   Autoshow            46 non-null     bool
#  6   Wheelspin           46 non-null     bool
#  7   Collection Journal  46 non-null     bool
# dtypes: bool(3), int64(1), str(4)
# memory usage: 2.3 KB

# %% [markdown]
# ### Dataframe to csv

# %%
df_wheelspin.to_csv(filename + "-wheelspin" + ".csv", index=False)

# %%
df_test = df_lite[(df_lite["Rarity"] == "COMMON") & (df_lite["Wheelspin"] == True)]
df_test = df_test.sort_values(["Value"], ascending=False)
df_test.head()
# Out:
#              Brand                                            Vehicle   Value  \
# 131        DeBerti  Toyota Tacoma TRD 'The Performance Truck' 2019...  250000
# 414  Mercedes-Benz           AMG Hammer Coupe 1987Autoshow, Wheelspin  225000
# 503        Porsche             Taycan Turbo S 2020Autoshow, Wheelspin  200000
# 55            Audi                 RS 4 Avant 2001Autoshow, Wheelspin  175000
# 220           Ford        Mustang SVT Cobra R 2000Autoshow, Wheelspin  153000
#
#      Rarity     PI  Autoshow  Hard to Find  Wheelspin  Aftermarket Car  \
# 131  COMMON  S1717      True         False       True            False
# 414  COMMON   B565      True         False       True            False
# 503  COMMON  S1725      True         False       True            False
# 55   COMMON   B544      True         False       True            False
# 220  COMMON   B528      True         False       True            False
#
#      Collection Journal
# 131               False
# 414               False
# 503               False
# 55                False
# 220               False
