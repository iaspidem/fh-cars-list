# %%
import pandas as pd

# %% [markdown]
# # Import raw data for preprocessing

# %%
filename = "FH4-cars-list"
tables = pd.read_html("raw-website/" + filename + ".htm")
df = tables[1]
df.head(10)
# Out:
#    Image                                          Vehicle   🔓   🦄   📅  \
# 0    NaN                  Abarth 124 Spider 2017 Autoshow NaN NaN NaN
# 1    NaN                Abarth 595 esseesse 1968 Autoshow NaN NaN NaN
# 2    NaN                 Abarth 695 Biposto 2016 Autoshow NaN NaN NaN
# 3    NaN                    Abarth Fiat 131 1980 Autoshow NaN NaN NaN
# 4    NaN               Acura Integra Type-R 2001 Autoshow NaN NaN NaN
# 5    NaN                   Acura RSX Type-S 2002 Autoshow NaN NaN NaN
# 6    NaN                          Acura NSX 2017 Autoshow NaN NaN NaN
# 7    NaN  Alfa Romeo 155 Q4 1992 A "Hard-to-Find" vehicle NaN NaN NaN
# 8    NaN                      Alfa Romeo 4C 2014 Autoshow NaN NaN NaN
# 9    NaN         Alfa Romeo 8C Competizione 2007 Autoshow NaN NaN NaN
#
#               Value   Sp   Ha   Ac    La   Br     PI
# 0  43,500 CR COMMON  6.0  5.9  5.6   7.6  5.4   C577
# 1  35,000 CR COMMON  3.9  4.0  3.7   4.9  4.0   D100
# 2    48,000 CR RARE  5.7  6.3  5.9   7.5  6.4   B607
# 3  38,000 CR COMMON  5.5  4.7  5.5   7.1  4.5   D449
# 4  25,000 CR COMMON  6.3  5.8  5.6   6.9  5.4   C596
# 5  25,000 CR COMMON  6.3  5.8  5.6   6.7  5.4   C588
# 6   170,000 CR RARE  7.4  7.6  9.6  10.0  8.3  S1850
# 7   250,000 CR EPIC  6.2  5.0  5.8   7.8  4.7   C541
# 8    74,000 CR RARE  6.6  7.1  6.5   8.8  7.0   A770
# 9   300,000 CR EPIC  7.5  6.6  6.6   8.2  6.8   A777

# %% [markdown]
# ## Remove redundant columns

# %%
columns_to_drop = [0, 2, 3, 4]
df = df.drop(df.columns[columns_to_drop], axis=1)
df.head()
# Out:
#                               Vehicle             Value   Sp   Ha   Ac   La  \
# 0     Abarth 124 Spider 2017 Autoshow  43,500 CR COMMON  6.0  5.9  5.6  7.6
# 1   Abarth 595 esseesse 1968 Autoshow  35,000 CR COMMON  3.9  4.0  3.7  4.9
# 2    Abarth 695 Biposto 2016 Autoshow    48,000 CR RARE  5.7  6.3  5.9  7.5
# 3       Abarth Fiat 131 1980 Autoshow  38,000 CR COMMON  5.5  4.7  5.5  7.1
# 4  Acura Integra Type-R 2001 Autoshow  25,000 CR COMMON  6.3  5.8  5.6  6.9
#
#     Br    PI
# 0  5.4  C577
# 1  4.0  D100
# 2  6.4  B607
# 3  4.5  D449
# 4  5.4  C596

# %% [markdown]
# ## Expand abbreviated columns

# %%
df = df.rename(columns={"Sp": "Speed", "Ha": "Handling", "Ac": "Accel", "La": "Launch", "Br": "Braking", "Of": "OffRd"})
df.head()
# Out:
#                               Vehicle             Value  Speed  Handling  \
# 0     Abarth 124 Spider 2017 Autoshow  43,500 CR COMMON    6.0       5.9
# 1   Abarth 595 esseesse 1968 Autoshow  35,000 CR COMMON    3.9       4.0
# 2    Abarth 695 Biposto 2016 Autoshow    48,000 CR RARE    5.7       6.3
# 3       Abarth Fiat 131 1980 Autoshow  38,000 CR COMMON    5.5       4.7
# 4  Acura Integra Type-R 2001 Autoshow  25,000 CR COMMON    6.3       5.8
#
#    Accel  Launch  Braking    PI
# 0    5.6     7.6      5.4  C577
# 1    3.7     4.9      4.0  D100
# 2    5.9     7.5      6.4  B607
# 3    5.5     7.1      4.5  D449
# 4    5.6     6.9      5.4  C596

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 753 entries, 0 to 752
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Vehicle   753 non-null    str
#  1   Value     753 non-null    str
#  2   Speed     753 non-null    float64
#  3   Handling  753 non-null    float64
#  4   Accel     753 non-null    float64
#  5   Launch    753 non-null    float64
#  6   Braking   753 non-null    float64
#  7   PI        753 non-null    str
# dtypes: float64(5), str(3)
# memory usage: 47.2 KB

# %% [markdown]
# ## Remove stat columns from df_lite

# %%
columns_to_drop = [2, 3, 4, 5, 6]
df_lite = df.drop(df.columns[columns_to_drop], axis=1)
df_lite.head()
# Out:
#                               Vehicle             Value    PI
# 0     Abarth 124 Spider 2017 Autoshow  43,500 CR COMMON  C577
# 1   Abarth 595 esseesse 1968 Autoshow  35,000 CR COMMON  D100
# 2    Abarth 695 Biposto 2016 Autoshow    48,000 CR RARE  B607
# 3       Abarth Fiat 131 1980 Autoshow  38,000 CR COMMON  D449
# 4  Acura Integra Type-R 2001 Autoshow  25,000 CR COMMON  C596

# %% [markdown]
# ## Split original Value column into Value and Rarity

# %%
df_lite.iloc[df_lite["Value"].str.contains("?", regex=False)].head()
# Out:
# Empty DataFrame
# Columns: [Vehicle, Value, PI]
# Index: []

# %%
df_lite[["Value", "Rarity"]] = df["Value"].str.split("CR", n=1, expand=True)
df_lite = df_lite.iloc[:, [0, 1, 3, 2]]

df_lite["Value"] = df_lite["Value"].str.replace(",", "")
df_lite["Value"] = df_lite["Value"].astype(int)
df_lite.head()
# Out:
#                               Vehicle  Value   Rarity    PI
# 0     Abarth 124 Spider 2017 Autoshow  43500   COMMON  C577
# 1   Abarth 595 esseesse 1968 Autoshow  35000   COMMON  D100
# 2    Abarth 695 Biposto 2016 Autoshow  48000     RARE  B607
# 3       Abarth Fiat 131 1980 Autoshow  38000   COMMON  D449
# 4  Acura Integra Type-R 2001 Autoshow  25000   COMMON  C596

# %% [markdown]
# ## Split original Vehicle column into Brand and Vehicle

# %%
df_lite.iloc[df_lite["Vehicle"].str.contains("_")].head()
# Out:
#                                                Vehicle    Value      Rarity  \
# 643  Quadra Turbo-R V-Tech 2058 Win the "_:NIGHTCIT...  1000000   LEGENDARY
#
#         PI
# 643  S1890

# %% [markdown]
# ### Isolate rows for 2-word vehicle brand names

# %%
df1 = df_lite.iloc[df_lite["Vehicle"].str.contains("Alfa Romeo|Alumi Craft|Aston Martin|Baldwin Motorsports|Land Rover|Local Motors|RJ Anderson|Spania GTA|W Motors")]
df1 = df1.loc[~df1["Vehicle"].str.contains("Hoonigan")]
df1.head()

# %%
df1["Vehicle"] = df1["Vehicle"].str.replace(" ", "_", n=1)
df1.head()

# %% [markdown]
# ### Separate filtering for Hot Wheels

# %%
df_hw = df_lite.iloc[df_lite["Vehicle"].str.contains("Hot Wheels")]
df_hw = df_hw.loc[~df_hw["Vehicle"].str.contains("Chrysler|Ford|Jeep|Pagani|Toyota|Zenvo")]
df_hw.head()

# %%
df_hw["Vehicle"] = df_hw["Vehicle"].str.replace(" ", "_", n=1)
df_hw.head()

# %% [markdown]
# ### Isolate rows for 3-word vehicle brand names

# %%
df2 = df_lite.iloc[df_lite["Vehicle"].str.contains("AMG Transport")]
df2.head()

# %%
df2["Vehicle"] = df2["Vehicle"].str.replace(" ", "_", n=2)
df2.head()

# %%
df_lite.update(df1)
df_lite.head()

# %%
df_lite.update(df2)
df_lite.head()

# %%
df_lite.update(df_hw)
df_lite.head()

# %% [markdown]
# ### Perform split

# %%
df_lite[["Brand", "Vehicle"]] = df_lite["Vehicle"].str.split(" ", n=1, expand=True)
df_lite = df_lite.iloc[:, [4, 0, 1, 2, 3]]
df_lite.head()

# %% [markdown]
# #### Error checking

# %%
df_verify = df_lite.iloc[df_lite["Vehicle"].str.contains("_")]
df_verify.head()

# %% [markdown]
# #### Replace underscores in Brand column with whitespace

# %%
df_lite["Brand"] = df_lite["Brand"].str.replace("_", " ")
df_lite.head()

# %% [markdown]
# ## Split Vehicle column into Vehicle and Collection

# %%
df_lite[["Vehicle", "Year", "Collection"]] = df_lite["Vehicle"].str.extract(r'^(.*)(\d{4})(.*)$')
df_lite = df_lite.iloc[:, [0, 1, 5, 2, 6, 3, 4]]
df_lite.loc[459, "Vehicle"] = "Regalia"
df_lite.loc[459, "Year"] = "723"
df_lite.loc[459, "Collection"] = "Gifted"
df_lite.head()

# %%
df_lite["Collection"].value_counts()

# %% [markdown]
# ## Sort by Brand then Year and Vehicle (ascending)

# %%
df_lite = df_lite.sort_values(["Brand", "Year", "Vehicle"], ascending=[True, True, True], key=lambda col: col.str.lower())
df_lite = df_lite.reset_index(drop=True)
df_lite.head(10)

# %% [markdown]
# ## Clean PI column

# %%
df_lite[["PI1", "PI2"]] = df_lite["PI"].str.split(r'(?<=D)|(?<=C)|(?<=B)|(?<=A)|(?<=S1)|(?<=S2)', n=1,
                                                                  expand=True)
df_lite.head()

# %%
df_lite["PI1"].value_counts()
# "A" is the most common class
# followed by C
# then S1

# %%
df_lite["PI2"].value_counts()
# S1 900 is the most common PI value

# %%
df_lite["PI"] = df_lite["PI1"] + " " + df_lite["PI2"]
df_lite = df_lite.drop(["PI1", "PI2"], axis="columns")
df_lite.head()

# %%
df_lite["Owned"] = pd.Series(dtype="string")
df_lite.head()

# %% [markdown]
# ## Sort by lowest to highest cost

# %%
df_lite.dtypes

# %%
df_lite["Value"] = df_lite["Value"].astype(str)

# %%
df_price = df_lite.sort_values(["Brand", "Value"], ascending=[True, True], key=lambda col: col.str.lower())
df_price = df_price.reset_index(drop=True)
df_price.head(10)

# %% [markdown]
# ### Convert dataframe to csv

# %%
df_lite.to_csv("FH3/FH3-0-masterlist.csv", index=False, encoding="utf-8-sig")
df_price.to_csv("FH3/FH3-1-price.csv", index=False, encoding="utf-8-sig")
