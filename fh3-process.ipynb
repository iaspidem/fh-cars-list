# %%
import pandas as pd

# %% [markdown]
# # Import raw data for preprocessing

# %%
filename = "FH3-cars-list"
tables = pd.read_html("raw-website/" + filename + ".htm")
df = tables[1]
df.head(10)
# Out:
#                                              Vehicle   📅  \
# 0                   Abarth 500 esseesse 2010Autoshow NaN
# 1                   Abarth 595 esseesse 1968Autoshow NaN
# 2                    Abarth 695 Biposto 2016Autoshow NaN
# 3                       Abarth Fiat 131 1980Autoshow NaN
# 4                  Acura Integra Type-R 2001Autoshow NaN
# 5  Acura NSX 2017Autoshow (DLC: Alpinestars Car P... NaN
# 6                      Acura RSX Type-S 2002Autoshow NaN
# 7                         Alfa Romeo 4C 2014Autoshow NaN
# 8            Alfa Romeo 8C Competizione 2007Autoshow NaN
# 9                Alfa Romeo 33 Stradale 1968Autoshow NaN
#
#                            Value   Sp   Ha   Ac    La   Br     PI
# 0             35,000 CRHot Hatch  5.0  5.8  6.4   6.7  5.9   C563
# 1         35,000 CRCult Classics  3.0  3.6  3.0   3.2  3.0   D100
# 2             48,000 CRHot Hatch  5.0  6.6  6.8   6.9  7.7   B625
# 3         38,000 CRClassic Rally  4.8  4.9  6.1   6.3  4.2   D477
# 4       25,000 CRRetro Hot Hatch  5.7  5.8  6.6   6.8  5.5   C571
# 5     170,000 CRModern Supercars  7.0  7.6  9.0  10.0  9.3  S1868
# 6             25,000 CRHot Hatch  5.7  5.8  6.6   6.7  5.5   C568
# 7  74,000 CREuropean Sports Cars  6.0  7.0  8.0   8.5  8.0   A758
# 8              300,000 CRGT Cars  7.2  6.8  8.1   8.1  7.8   A766
# 9    10,000,000 CRClassic Racers  6.4  6.0  8.3   8.0  6.1   B648

# %% [markdown]
# ## Remove redundant columns

# %%
columns_to_drop = [1]
df = df.drop(df.columns[columns_to_drop], axis=1)
df.head()
# Out:
#                              Vehicle                     Value   Sp   Ha   Ac  \
# 0   Abarth 500 esseesse 2010Autoshow        35,000 CRHot Hatch  5.0  5.8  6.4
# 1   Abarth 595 esseesse 1968Autoshow    35,000 CRCult Classics  3.0  3.6  3.0
# 2    Abarth 695 Biposto 2016Autoshow        48,000 CRHot Hatch  5.0  6.6  6.8
# 3       Abarth Fiat 131 1980Autoshow    38,000 CRClassic Rally  4.8  4.9  6.1
# 4  Acura Integra Type-R 2001Autoshow  25,000 CRRetro Hot Hatch  5.7  5.8  6.6
#
#     La   Br    PI
# 0  6.7  5.9  C563
# 1  3.2  3.0  D100
# 2  6.9  7.7  B625
# 3  6.3  4.2  D477
# 4  6.8  5.5  C571

# %% [markdown]
# ## Expand abbreviated columns

# %%
df = df.rename(columns={"Sp": "Speed", "Ha": "Handling", "Ac": "Accel", "La": "Launch", "Br": "Braking", "Of": "OffRd"})
df.head()
# Out:
#                              Vehicle                     Value  Speed  \
# 0   Abarth 500 esseesse 2010Autoshow        35,000 CRHot Hatch    5.0
# 1   Abarth 595 esseesse 1968Autoshow    35,000 CRCult Classics    3.0
# 2    Abarth 695 Biposto 2016Autoshow        48,000 CRHot Hatch    5.0
# 3       Abarth Fiat 131 1980Autoshow    38,000 CRClassic Rally    4.8
# 4  Acura Integra Type-R 2001Autoshow  25,000 CRRetro Hot Hatch    5.7
#
#    Handling  Accel  Launch  Braking    PI
# 0       5.8    6.4     6.7      5.9  C563
# 1       3.6    3.0     3.2      3.0  D100
# 2       6.6    6.8     6.9      7.7  B625
# 3       4.9    6.1     6.3      4.2  D477
# 4       5.8    6.6     6.8      5.5  C571

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 524 entries, 0 to 523
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Vehicle   524 non-null    str
#  1   Value     524 non-null    str
#  2   Speed     524 non-null    float64
#  3   Handling  524 non-null    float64
#  4   Accel     524 non-null    float64
#  5   Launch    524 non-null    float64
#  6   Braking   524 non-null    float64
#  7   PI        524 non-null    str
# dtypes: float64(5), str(3)
# memory usage: 32.9 KB

# %% [markdown]
# ## Remove stat columns from df_lite

# %%
columns_to_drop = [2, 3, 4, 5, 6]
df_lite = df.drop(df.columns[columns_to_drop], axis=1)
df_lite.head()
# Out:
#                              Vehicle                     Value    PI
# 0   Abarth 500 esseesse 2010Autoshow        35,000 CRHot Hatch  C563
# 1   Abarth 595 esseesse 1968Autoshow    35,000 CRCult Classics  D100
# 2    Abarth 695 Biposto 2016Autoshow        48,000 CRHot Hatch  B625
# 3       Abarth Fiat 131 1980Autoshow    38,000 CRClassic Rally  D477
# 4  Acura Integra Type-R 2001Autoshow  25,000 CRRetro Hot Hatch  C571

# %% [markdown]
# ## Split original Value column into Value and Car Type

# %%
df_lite.iloc[df_lite["Value"].str.contains("?", regex=False)].head()
# Out:
# Empty DataFrame
# Columns: [Vehicle, Value, PI]
# Index: []

# %%
df_lite[["Value", "Car Type"]] = df["Value"].str.split("CR", n=1, expand=True)
df_lite = df_lite.iloc[:, [0, 1, 3, 2]]

df_lite["Value"] = df_lite["Value"].str.replace(",", "")
df_lite["Value"] = df_lite["Value"].astype(int)
df_lite.head()
# Out:
#                              Vehicle  Value         Car Type    PI
# 0   Abarth 500 esseesse 2010Autoshow  35000        Hot Hatch  C563
# 1   Abarth 595 esseesse 1968Autoshow  35000    Cult Classics  D100
# 2    Abarth 695 Biposto 2016Autoshow  48000        Hot Hatch  B625
# 3       Abarth Fiat 131 1980Autoshow  38000    Classic Rally  D477
# 4  Acura Integra Type-R 2001Autoshow  25000  Retro Hot Hatch  C571

# %% [markdown]
# ## Split original Vehicle column into Brand and Vehicle

# %%
df_lite.iloc[df_lite["Vehicle"].str.contains("_")].head()
# Out:
# Empty DataFrame
# Columns: [Vehicle, Value, Car Type, PI]
# Index: []

# %% [markdown]
# ### Isolate rows for 2-word vehicle brand names

# %%
df1 = df_lite.iloc[df_lite["Vehicle"].str.contains("Alfa Romeo|Alumi Craft|Aston Martin|Baldwin Motorsports|Land Rover|Local Motors|RJ Anderson|Spania GTA|W Motors")]
df1 = df1.loc[~df1["Vehicle"].str.contains("Hoonigan")]
df1.head()
# Out:
#                                               Vehicle     Value  \
# 7                          Alfa Romeo 4C 2014Autoshow     74000
# 8             Alfa Romeo 8C Competizione 2007Autoshow    300000
# 9                 Alfa Romeo 33 Stradale 1968Autoshow  10000000
# 10                     Alfa Romeo 155 Q4 1992Autoshow     25000
# 11  Alfa Romeo Giulia Sprint GTA Stradale 1965Auto...    300000
#
#                 Car Type    PI
# 7   European Sports Cars  A758
# 8                GT Cars  A766
# 9         Classic Racers  B648
# 10         Retro Saloons  C578
# 11         Rare Classics  D252

# %%
df1["Vehicle"] = df1["Vehicle"].str.replace(" ", "_", n=1)
df1.head()
# Out:
#                                               Vehicle     Value  \
# 7                          Alfa_Romeo 4C 2014Autoshow     74000
# 8             Alfa_Romeo 8C Competizione 2007Autoshow    300000
# 9                 Alfa_Romeo 33 Stradale 1968Autoshow  10000000
# 10                     Alfa_Romeo 155 Q4 1992Autoshow     25000
# 11  Alfa_Romeo Giulia Sprint GTA Stradale 1965Auto...    300000
#
#                 Car Type    PI
# 7   European Sports Cars  A758
# 8                GT Cars  A766
# 9         Classic Racers  B648
# 10         Retro Saloons  C578
# 11         Rare Classics  D252

# %% [markdown]
# ### Separate filtering for Hot Wheels

# %%
df_hw = df_lite.iloc[df_lite["Vehicle"].str.contains("Hot Wheels")]
df_hw = df_hw.loc[~df_hw["Vehicle"].str.contains("Chrysler|Ford|Jeep|Pagani|Toyota|Zenvo")]
df_hw.head()
# Out:
#                                                Vehicle   Value  \
# 255  Hot Wheels Bone Shaker 2005Autoshow (DLC: Hot ...  150000
# 256  Hot Wheels Mustang 2005Autoshow (DLC: Hot Whee...   50000
# 257  Hot Wheels Rip Rod 2012Autoshow (DLC: Hot Whee...   75000
# 258  Hot Wheels Twin Mill 1969Autoshow (DLC: Hot Wh...  110000
#
#                Car Type     PI
# 255    Rods and Customs   A797
# 256  Extreme Track Toys  S1900
# 257             Buggies   B700
# 258    Rods and Customs  S1900

# %%
df_hw["Vehicle"] = df_hw["Vehicle"].str.replace(" ", "_", n=1)
df_hw.head()
# Out:
#                                                Vehicle   Value  \
# 255  Hot_Wheels Bone Shaker 2005Autoshow (DLC: Hot ...  150000
# 256  Hot_Wheels Mustang 2005Autoshow (DLC: Hot Whee...   50000
# 257  Hot_Wheels Rip Rod 2012Autoshow (DLC: Hot Whee...   75000
# 258  Hot_Wheels Twin Mill 1969Autoshow (DLC: Hot Wh...  110000
#
#                Car Type     PI
# 255    Rods and Customs   A797
# 256  Extreme Track Toys  S1900
# 257             Buggies   B700
# 258    Rods and Customs  S1900

# %% [markdown]
# ### Isolate rows for 3-word vehicle brand names

# %%
df2 = df_lite.iloc[df_lite["Vehicle"].str.contains("AMG Transport")]
df2.head()
# Out:
#                                               Vehicle   Value  \
# 19  AMG Transport Dynamics M12S Warthog CST 2554Au...  850000
#
#            Car Type    PI
# 19  Extreme Offroad  A800

# %%
df2["Vehicle"] = df2["Vehicle"].str.replace(" ", "_", n=2)
df2.head()
# Out:
#                                               Vehicle   Value  \
# 19  AMG_Transport_Dynamics M12S Warthog CST 2554Au...  850000
#
#            Car Type    PI
# 19  Extreme Offroad  A800

# %%
df_lite.update(df1)
df_lite.head()
# Out:
#                              Vehicle  Value         Car Type    PI
# 0   Abarth 500 esseesse 2010Autoshow  35000        Hot Hatch  C563
# 1   Abarth 595 esseesse 1968Autoshow  35000    Cult Classics  D100
# 2    Abarth 695 Biposto 2016Autoshow  48000        Hot Hatch  B625
# 3       Abarth Fiat 131 1980Autoshow  38000    Classic Rally  D477
# 4  Acura Integra Type-R 2001Autoshow  25000  Retro Hot Hatch  C571

# %%
df_lite.update(df2)
df_lite.head()
# Out:
#                              Vehicle  Value         Car Type    PI
# 0   Abarth 500 esseesse 2010Autoshow  35000        Hot Hatch  C563
# 1   Abarth 595 esseesse 1968Autoshow  35000    Cult Classics  D100
# 2    Abarth 695 Biposto 2016Autoshow  48000        Hot Hatch  B625
# 3       Abarth Fiat 131 1980Autoshow  38000    Classic Rally  D477
# 4  Acura Integra Type-R 2001Autoshow  25000  Retro Hot Hatch  C571

# %%
df_lite.update(df_hw)
df_lite.head()
# Out:
#                              Vehicle  Value         Car Type    PI
# 0   Abarth 500 esseesse 2010Autoshow  35000        Hot Hatch  C563
# 1   Abarth 595 esseesse 1968Autoshow  35000    Cult Classics  D100
# 2    Abarth 695 Biposto 2016Autoshow  48000        Hot Hatch  B625
# 3       Abarth Fiat 131 1980Autoshow  38000    Classic Rally  D477
# 4  Acura Integra Type-R 2001Autoshow  25000  Retro Hot Hatch  C571

# %% [markdown]
# ### Perform split

# %%
df_lite[["Brand", "Vehicle"]] = df_lite["Vehicle"].str.split(" ", n=1, expand=True)
df_lite = df_lite.iloc[:, [4, 0, 1, 2, 3]]
df_lite.head()
# Out:
#     Brand                      Vehicle  Value         Car Type    PI
# 0  Abarth    500 esseesse 2010Autoshow  35000        Hot Hatch  C563
# 1  Abarth    595 esseesse 1968Autoshow  35000    Cult Classics  D100
# 2  Abarth     695 Biposto 2016Autoshow  48000        Hot Hatch  B625
# 3  Abarth        Fiat 131 1980Autoshow  38000    Classic Rally  D477
# 4   Acura  Integra Type-R 2001Autoshow  25000  Retro Hot Hatch  C571

# %% [markdown]
# #### Error checking

# %%
df_verify = df_lite.iloc[df_lite["Vehicle"].str.contains("_")]
df_verify.head()
# Out:
# Empty DataFrame
# Columns: [Brand, Vehicle, Value, Car Type, PI]
# Index: []

# %% [markdown]
# #### Replace underscores in Brand column with whitespace

# %%
df_lite["Brand"] = df_lite["Brand"].str.replace("_", " ")
df_lite.head()
# Out:
#     Brand                      Vehicle  Value         Car Type    PI
# 0  Abarth    500 esseesse 2010Autoshow  35000        Hot Hatch  C563
# 1  Abarth    595 esseesse 1968Autoshow  35000    Cult Classics  D100
# 2  Abarth     695 Biposto 2016Autoshow  48000        Hot Hatch  B625
# 3  Abarth        Fiat 131 1980Autoshow  38000    Classic Rally  D477
# 4   Acura  Integra Type-R 2001Autoshow  25000  Retro Hot Hatch  C571

# %% [markdown]
# ## Split Vehicle column into Vehicle and Collection

# %%
df_lite[["Vehicle", "Year", "Collection"]] = df_lite["Vehicle"].str.extract(r'^(.*)(\d{4})(.*)$')
df_lite = df_lite.iloc[:, [0, 1, 5, 2, 6, 3, 4]]
df_lite.loc[459, "Vehicle"] = "Regalia"
df_lite.loc[459, "Year"] = "723"
df_lite.loc[459, "Collection"] = "Gifted"
df_lite.head()
# Out:
#     Brand          Vehicle  Year  Value Collection         Car Type    PI
# 0  Abarth    500 esseesse   2010  35000   Autoshow        Hot Hatch  C563
# 1  Abarth    595 esseesse   1968  35000   Autoshow    Cult Classics  D100
# 2  Abarth     695 Biposto   2016  48000   Autoshow        Hot Hatch  B625
# 3  Abarth        Fiat 131   1980  38000   Autoshow    Classic Rally  D477
# 4   Acura  Integra Type-R   2001  25000   Autoshow  Retro Hot Hatch  C571

# %%
df_lite["Collection"].value_counts()
# Out:
# Collection
# Autoshow                                       349
# Wheelspin                                       28
# Forzathon                                       26
# Barn Find                                       17
# Autoshow (DLC: All-Stars Car Pack)              11
# Autoshow (DLC: Hot Wheels Expansion)             9
# Autoshow (DLC: Blizzard Mountain Expansion)      9
# Autoshow (DLC: Duracell Car Pack)                8
# Autoshow (DLC: Porsche Car Pack)                 8
# Autoshow (DLC: Alpinestars Car Pack)             7
# Autoshow (DLC: Mountain Dew Car Pack)            7
# Autoshow (DLC: Playseat Car Pack)                7
# Autoshow (DLC: The Smoking Tire Car Pack)        7
# Autoshow (DLC: Rockstar Energy Car Pack)         7
# Autoshow (DLC: Logitech G Car Pack)              7
# Autoshow (DLC: Hoonigan Car Pack)                7
# Autoshow (DLC: VIP)                              5
# Barn Find (Forzathon)                            2
# Gifted                                           2
# Barn Find (DLC: Hot Wheels Expansion)            1
# Name: count, dtype: int64

# %% [markdown]
# ## Sort by Brand then Year and Vehicle (ascending)

# %%
df_lite = df_lite.sort_values(["Brand", "Year", "Vehicle"], ascending=[True, True, True], key=lambda col: col.str.lower())
df_lite = df_lite.reset_index(drop=True)
df_lite.head(10)
# Out:
#         Brand                      Vehicle  Year     Value  \
# 0      Abarth                595 esseesse   1968     35000
# 1      Abarth                    Fiat 131   1980     38000
# 2      Abarth                500 esseesse   2010     35000
# 3      Abarth                 695 Biposto   2016     48000
# 4       Acura              Integra Type-R   2001     25000
# 5       Acura                  RSX Type-S   2002     25000
# 6       Acura                         NSX   2017    170000
# 7  Alfa Romeo  Giulia Sprint GTA Stradale   1965    300000
# 8  Alfa Romeo                  Giulia TZ2   1965   1000000
# 9  Alfa Romeo                 33 Stradale   1968  10000000
#
#                              Collection          Car Type     PI
# 0                              Autoshow     Cult Classics   D100
# 1                              Autoshow     Classic Rally   D477
# 2                              Autoshow         Hot Hatch   C563
# 3                              Autoshow         Hot Hatch   B625
# 4                              Autoshow   Retro Hot Hatch   C571
# 5                              Autoshow         Hot Hatch   C568
# 6  Autoshow (DLC: Alpinestars Car Pack)  Modern Supercars  S1868
# 7                              Autoshow     Rare Classics   D252
# 8                              Autoshow    Classic Racers   C573
# 9                              Autoshow    Classic Racers   B648

# %% [markdown]
# ## Clean PI column

# %%
df_lite[["PI1", "PI2"]] = df_lite["PI"].str.split(r'(?<=D)|(?<=C)|(?<=B)|(?<=A)|(?<=S1)|(?<=S2)', n=1,
                                                                  expand=True)
df_lite.head()
# Out:
#     Brand          Vehicle  Year  Value Collection         Car Type    PI PI1  \
# 0  Abarth    595 esseesse   1968  35000   Autoshow    Cult Classics  D100   D
# 1  Abarth        Fiat 131   1980  38000   Autoshow    Classic Rally  D477   D
# 2  Abarth    500 esseesse   2010  35000   Autoshow        Hot Hatch  C563   C
# 3  Abarth     695 Biposto   2016  48000   Autoshow        Hot Hatch  B625   B
# 4   Acura  Integra Type-R   2001  25000   Autoshow  Retro Hot Hatch  C571   C
#
#    PI2
# 0  100
# 1  477
# 2  563
# 3  625
# 4  571

# %%
df_lite["PI1"].value_counts()
# "A" is the most common class
# followed by C
# then S1
# Out:
# PI1
# A     118
# C     111
# S1     93
# B      85
# D      68
# S2     49
# Name: count, dtype: int64

# %%
df_lite["PI2"].value_counts()
# S1 900 is the most common PI value
# Out:
# PI2
# 900    13
# 100     9
# 800     7
# 715     6
# 524     5
#        ..
# 512     1
# 564     1
# 705     1
# 919     1
# 924     1
# Name: count, Length: 328, dtype: int64

# %%
df_lite["PI"] = df_lite["PI1"] + " " + df_lite["PI2"]
df_lite = df_lite.drop(["PI1", "PI2"], axis="columns")
df_lite.head()
# Out:
#     Brand          Vehicle  Year  Value Collection         Car Type     PI
# 0  Abarth    595 esseesse   1968  35000   Autoshow    Cult Classics  D 100
# 1  Abarth        Fiat 131   1980  38000   Autoshow    Classic Rally  D 477
# 2  Abarth    500 esseesse   2010  35000   Autoshow        Hot Hatch  C 563
# 3  Abarth     695 Biposto   2016  48000   Autoshow        Hot Hatch  B 625
# 4   Acura  Integra Type-R   2001  25000   Autoshow  Retro Hot Hatch  C 571

# %%
df_lite["Owned"] = pd.Series(dtype="string")
df_lite.head()
# Out:
#     Brand          Vehicle  Year  Value Collection         Car Type     PI  \
# 0  Abarth    595 esseesse   1968  35000   Autoshow    Cult Classics  D 100
# 1  Abarth        Fiat 131   1980  38000   Autoshow    Classic Rally  D 477
# 2  Abarth    500 esseesse   2010  35000   Autoshow        Hot Hatch  C 563
# 3  Abarth     695 Biposto   2016  48000   Autoshow        Hot Hatch  B 625
# 4   Acura  Integra Type-R   2001  25000   Autoshow  Retro Hot Hatch  C 571
#
#   Owned
# 0  <NA>
# 1  <NA>
# 2  <NA>
# 3  <NA>
# 4  <NA>

# %% [markdown]
# ### Convert dataframe to csv

# %%
df_lite.to_csv("FH3/FH3-0-masterlist.csv", index=False, encoding="utf-8-sig")
